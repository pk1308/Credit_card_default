# %%
from CCdefault.app_src.stage_01_data_validation import DataValidation
from CCdefault.app_src.stage_00_data_ingestion import DataIngestion
from CCdefault.app_src.stage_02_data_transformation import DataTransformation
from CCdefault.app_src.stage_03_model_trainer import ModelTrainer
from CCdefault.app_src.stage_04_model_evalution import ModelEvaluation
from CCdefault.app_config.configuration import Configuration

# %%
from CCdefault.app_entity.artifacts_entity import DataIngestionArtifact, DataValidationArtifact , DataTransformationArtifact , ModelTrainerArtifact ,ModelEvaluationArtifact
from CCdefault.app_entity.config_entity import DataValidationConfig , DataIngestionConfig , DataTransformationConfig , ModelTrainerConfig , ModelEvaluationConfig

# %%
# %load_ext autoreload

# %%
config = Configuration()
# Out:
# Training pipeline config: TrainingPipelineConfig(artifact_dir='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact', pipeline_name='CCdefault')

# %%
data_ingestion_config = config.get_data_ingestion_config()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Data Ingestion config.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# ...

# %%
data_ingestion = DataIngestion(data_ingestion_config)

# %%
data_ingestion_artifact = data_ingestion.initiate_data_ingestion()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Data Ingestion started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ...
# 100%|██████████| 0.98M/0.98M [00:00<00:00, 2.15MB/s]
# Dataset downloaded successfully file name : default-of-credit-card-clients-dataset.zip
# Dataset moved to raw data folder : /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/raw_data/20220807174215/default-of-credit-card-clients-dataset.zip
# Dataset unzipped successfully
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Data splitting.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# get_the_last_experiment_file_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/20220807174215/Train.csv
# dir_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/
# ...

# %%
data_ingestion_artifact
# Out:
# DataIngestionArtifact(train_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/20220807174215/Train.csv', test_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/20220807174215/Test.csv', is_ingested=True, message='Data ingestion completed successfully.')

# %%
import os
os.path.isfile(data_ingestion_artifact.train_file_path)
# Out:
# True

# %%
os.path.isfile(data_ingestion_artifact.test_file_path)
# Out:
# True

# %%
data_validation_config = config.get_data_validation_config()

# %%
data_validation_config
# Out:
# DataValidationConfig(data_validated_artifact_dir='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/20220807174215/data_validated', schema_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/config/schema.yaml', report_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/20220807174215/report/report.json', report_page_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/20220807174215/report/report.html', data_validated_test_collection='data_validated_test', data_validated_train_collection='data_validated_train')

# %%
data_validation = DataValidation(data_validation_config, data_ingestion_artifact)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Data Validation log started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
data_validation_artifact = data_validation.initiate_data_validation()
# Out:
# get_the_last_experiment_file_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/20220807174215/data_validated/Test.csv
# dir_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/
# get_the_last_experiment_file_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/20220807174215/data_validated/Train.csv
# dir_name: /home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage01_data_validation/
# No previous experiment file found
# Checking if training and test file is available
# Is train and test file exists?-> True
# Validating dataset schema
# Dataset schema validation completed
# Validation_status True
# ...

# %%
data_transformation_config = config.get_data_transformation_config()

# %%
data_trasformation = DataTransformation(data_transformation_config=data_transformation_config, data_validation_artifact=data_validation_artifact ,data_ingestion_artifact= data_ingestion_artifact )
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Data Transformation log started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
data_ingestion_artifact
# Out:
# DataIngestionArtifact(train_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/20220807174215/Train.csv', test_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage00_data_ingestion/ingested_data/20220807174215/Test.csv', is_ingested=True, message='Data ingestion completed successfully.')

# %%
data_trasformation_artifact = data_trasformation.initiate_data_transformation()
# Out:
# Obtaining preprocessing object.
# Target column name : default.payment.next.month
# Obtaining training and test file path.
# Loading training and test data as pandas dataframe.
# Memory usage of dataframe is 4.39 MB
# Memory usage after optimization is: 1.44 MB
# Decreased by 67.2%
# Memory usage of dataframe is 1.10 MB
# Memory usage after optimization is: 0.36 MB
# Decreased by 67.2%
# Splitting input and target feature from training and testing dataframe.
# Applying preprocessing object on training dataframe and testing dataframe
# total cluster :3
# Transforming data
# Transforming data
# Saving transformed training and testing array.
# Saving preprocessing object.
# ...

# %%
model_ingestion_config = config.get_model_trainer_config()
# Out:
# Model trainer config: ModelTrainerConfig(model_config_file_path='config/model.yaml', base_accuracy=0.3, trained_model_file_path='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage03_model_training/trained_model/20220807174215/model.pkl', model_report_dir='/home/pk/Desktop/MachineLearning/project/Credit_card_default/CCdefault/app_artifact/stage03_model_training/model_report/20220807174215')

# %%
model_trainer = ModelTrainer(model_ingestion_config, data_trasformation_artifact)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Model trainer log started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
model_trainer_artifact = model_trainer.initiate_model_trainer()
# Out:
# Loading transformed training dataset
# Training model for cluster 0.0
# Extracting model config file path
# Initializing model factory class using above model config file: config/model.yaml
# Expected accuracy: 0.3
# Initiating operation model selection
# Started Initializing model from config file
# Executing command: from <module 'sklearn.ensemble' from '/home/pk/Desktop/MachineLearning/project/Creditcard/venv/lib/python3.7/site-packages/sklearn/ensemble/__init__.py'> import RandomForestClassifier
# Executing command: from <module 'catboost' from '/home/pk/Desktop/MachineLearning/project/Creditcard/venv/lib/python3.7/site-packages/catboost/__init__.py'> import CatBoostClassifier
# Executing command: from <module 'xgboost' from '/home/pk/Desktop/MachineLearning/project/Creditcard/venv/lib/python3.7/site-packages/xgboost/__init__.py'> import XGBClassifier
# ...

# %%
model_trainer_artifact

# %%
model_evaluation_config = config.get_model_evaluation_config()

# %%
model_evaluation_config

# %%
model_evalution = ModelEvaluation(model_evaluation_config, data_ingestion_artifact, data_validation_artifact, model_trainer_artifact)

# %%
model_evaluation_artifact = model_evalution.initiate_model_evaluation()
